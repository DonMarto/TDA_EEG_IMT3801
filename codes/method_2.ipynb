# %%
## Import necessary libraries

import mne
import numpy as np
import matplotlib.pyplot as plt
# import torch
from scipy.io import loadmat
from scipy.special import sph_harm
from numpy.linalg import solve
import json
from scipy.interpolate import RegularGridInterpolator

# %%
import numpy as np, matplotlib.pyplot as plt, os
from matplotlib import gridspec
from scipy import ndimage
from ripser import ripser
from persim import plot_diagrams
import gudhi as gd
from sklearn.datasets import load_digits
try:
    from gtda.time_series import TakensEmbedding, SlidingWindow
    from gtda.homology import VietorisRipsPersistence
    from gtda.plotting import plot_diagram
    HAVE_GIOTTO = True
except Exception:
    HAVE_GIOTTO = False

# %%
good = [2, 3, 4, 6, 7, 9, 11, 12, 13, 14, 15, 16, 18, 19, 20, 21, 22, 24, 25, 26, 27, 28, 30, 31, 33, 34, 36, 38, 40, 41, 42, 44, 45, 46, 48, 49, 50, 51, 52, 53, 54, 56, 57, 58, 59, 60, 65]
good = np.array(good) - 1
subjects = ["01", "02", "04", "09", "15", "37", "79"]
auds = [f"{i:02d}" for i in range(1, 24)]

bad = set(range(65)) - set(good)

san_disk = 'D:/Universidad/2025_2/TDA/data'

# %%
def takens_numpy(x, m=3, tau=10):
    """Takens embedding simple para una serie 1D -> matriz (N-(m-1)tau, m)."""
    N = len(x) - (m-1)*tau
    if N <= 0:
        raise ValueError("Serie muy corta para estos parámetros (m, tau).")
    return np.vstack([x[i:i+N] for i in range(0, m*tau, tau)]).T

# %%
n_phi = 128
n_theta = 64 

# Angular grids (depends on your definition!)
phi = np.linspace(-np.pi, np.pi, n_phi)
theta = np.linspace(0, np.pi, n_theta)

# Target Cartesian grid
N = 50
x = np.linspace(-1, 1, N)
y = np.linspace(-1, 1, N)
X, Y = np.meshgrid(x, y)
R = np.sqrt(X**2 + Y**2)

# Mask for the unit disk
mask = R <= 1

# Map to spherical angles (example: simple azimuthal projection)
phi_map = np.arctan2(Y, X)
theta_map = R * (np.pi / 2)


for m1 in range(len(subjects)):
    for n1 in range(len(auds)):
        m = 7-m1-1
        n = 23-n1-1
        for band in ["alpha", "theta", "beta"]:
            for speed in ["slow", "fast"]:
                bb = subjects[m]
                ut = auds[n]
                try:
                    interp_maps = np.load(f"{san_disk}/eegs/harmonics/{speed}/{band}/bb{bb}_ut{ut}.npy")
                    print(f"Working on bb{bb}_ut{ut}, band {band}, speed {speed}")
                except FileNotFoundError:
                    print(f"File for bb{bb}_ut{ut} not found, skipping.")
                    continue
                interp_maps = interp_maps[::10, :, :]
                movie = []
                for t in range(interp_maps.shape[0]):
                    interpolator = RegularGridInterpolator((phi, theta), interp_maps[t], bounds_error=False, fill_value=0)
                    pts = np.stack([phi_map[mask], theta_map[mask]], axis=-1)
                    vals = interpolator(pts)
                    frame = np.zeros((N, N))
                    frame[mask] = vals
                    movie.append(frame)
                movie = np.array(movie)
                
                
                for eid, emb in enumerate([3, 5, 7]):
                    for tid, tau in enumerate(["", "_tau10"]):                

                        results_emb2 = np.zeros((interp_maps.shape[0] - (tid*3 + 1)*(emb-1), emb, 7, 7))
                        results_emb3 = np.zeros((interp_maps.shape[0] - (tid*3 + 1)*(emb-1), emb, 16, 8))


                        for i in range(7):
                            for j in range(7):
                                reel = movie[:, i*7, j*7]  
                                emb2 = takens_numpy(reel, m=emb, tau=(tid*3 + 1))
                                results_emb2[:, :, i, j] = emb2    

                        for i in range(16):
                            for j in range(8):
                                reel = interp_maps[:, i*8, j*8]  
                                emb3 = takens_numpy(reel, m=emb, tau=(tid*3 + 1))
                                results_emb3[:, :, i, j] = emb3

                        with open(f'{san_disk}/eegs/method_2/{band}/{speed}/bb{bb}_ut{ut}_emb{emb}{tau}_square.json', 'w') as f:
                            json.dump(results_emb2.tolist(), f)

                        with open(f'{san_disk}/eegs/method_2/{band}/{speed}/bb{bb}_ut{ut}_emb{emb}{tau}_sphere.json', 'w') as f:
                            json.dump(results_emb3.tolist(), f)
# Out:
# Working on bb79_ut23, band alpha, speed slow
# Working on bb79_ut23, band alpha, speed fast
# Working on bb79_ut23, band theta, speed slow
# Working on bb79_ut23, band theta, speed fast
# Working on bb79_ut23, band beta, speed slow
# Working on bb79_ut23, band beta, speed fast
# Working on bb79_ut22, band alpha, speed slow
# Working on bb79_ut22, band alpha, speed fast
# Working on bb79_ut22, band theta, speed slow
# Working on bb79_ut22, band theta, speed fast
# Working on bb79_ut22, band beta, speed slow
# Working on bb79_ut22, band beta, speed fast
# Working on bb79_ut21, band alpha, speed slow
# Working on bb79_ut21, band alpha, speed fast
# Working on bb79_ut21, band theta, speed slow
# Working on bb79_ut21, band theta, speed fast
# Working on bb79_ut21, band beta, speed slow
# Working on bb79_ut21, band beta, speed fast
# Working on bb79_ut20, band alpha, speed slow
# Working on bb79_ut20, band alpha, speed fast
# Working on bb79_ut20, band theta, speed slow
# Working on bb79_ut20, band theta, speed fast
# Working on bb79_ut20, band beta, speed slow
# Working on bb79_ut20, band beta, speed fast
# Working on bb79_ut19, band alpha, speed slow
# Working on bb79_ut19, band alpha, speed fast
# Working on bb79_ut19, band theta, speed slow
# Working on bb79_ut19, band theta, speed fast
# Working on bb79_ut19, band beta, speed slow
# Working on bb79_ut19, band beta, speed fast
# Working on bb79_ut18, band alpha, speed slow
# Working on bb79_ut18, band alpha, speed fast
# Working on bb79_ut18, band theta, speed slow
# Working on bb79_ut18, band theta, speed fast
# Working on bb79_ut18, band beta, speed slow
# Working on bb79_ut18, band beta, speed fast
# Working on bb79_ut17, band alpha, speed slow
# Working on bb79_ut17, band alpha, speed fast
# Working on bb79_ut17, band theta, speed slow
# Working on bb79_ut17, band theta, speed fast
# Working on bb79_ut17, band beta, speed slow
# Working on bb79_ut17, band beta, speed fast
# Working on bb79_ut16, band alpha, speed slow
# Working on bb79_ut16, band alpha, speed fast
# Working on bb79_ut16, band theta, speed slow
# Working on bb79_ut16, band theta, speed fast
# Working on bb79_ut16, band beta, speed slow
# Working on bb79_ut16, band beta, speed fast
# Working on bb79_ut15, band alpha, speed slow
# Working on bb79_ut15, band alpha, speed fast
# Working on bb79_ut15, band theta, speed slow
# Working on bb79_ut15, band theta, speed fast
# Working on bb79_ut15, band beta, speed slow
# Working on bb79_ut15, band beta, speed fast
# Working on bb79_ut14, band alpha, speed slow
# Working on bb79_ut14, band alpha, speed fast
# Working on bb79_ut14, band theta, speed slow
# Working on bb79_ut14, band theta, speed fast
# Working on bb79_ut14, band beta, speed slow
# Working on bb79_ut14, band beta, speed fast
# Working on bb79_ut13, band alpha, speed slow
# File for bb79_ut13 not found, skipping.
# Working on bb79_ut13, band theta, speed slow
# File for bb79_ut13 not found, skipping.
# Working on bb79_ut13, band beta, speed slow
# File for bb79_ut13 not found, skipping.
# Working on bb79_ut12, band alpha, speed slow
# Working on bb79_ut12, band alpha, speed fast
# Working on bb79_ut12, band theta, speed slow
# Working on bb79_ut12, band theta, speed fast
# Working on bb79_ut12, band beta, speed slow
# Working on bb79_ut12, band beta, speed fast
# Working on bb79_ut11, band alpha, speed slow
# Working on bb79_ut11, band alpha, speed fast
# Working on bb79_ut11, band theta, speed slow
# Working on bb79_ut11, band theta, speed fast
# Working on bb79_ut11, band beta, speed slow
# Working on bb79_ut11, band beta, speed fast
# Working on bb79_ut10, band alpha, speed slow
# Working on bb79_ut10, band alpha, speed fast
# Working on bb79_ut10, band theta, speed slow
# Working on bb79_ut10, band theta, speed fast
# Working on bb79_ut10, band beta, speed slow
# Working on bb79_ut10, band beta, speed fast
# Working on bb79_ut09, band alpha, speed slow
# Working on bb79_ut09, band alpha, speed fast
# Working on bb79_ut09, band theta, speed slow
# Working on bb79_ut09, band theta, speed fast
# Working on bb79_ut09, band beta, speed slow
# Working on bb79_ut09, band beta, speed fast
# Working on bb79_ut08, band alpha, speed slow
# Working on bb79_ut08, band alpha, speed fast
# Working on bb79_ut08, band theta, speed slow
# Working on bb79_ut08, band theta, speed fast
# Working on bb79_ut08, band beta, speed slow
# Working on bb79_ut08, band beta, speed fast
# Working on bb79_ut07, band alpha, speed slow
# Working on bb79_ut07, band alpha, speed fast
# Working on bb79_ut07, band theta, speed slow
# Working on bb79_ut07, band theta, speed fast
# Working on bb79_ut07, band beta, speed slow
# Working on bb79_ut07, band beta, speed fast
# Working on bb79_ut06, band alpha, speed slow
# Working on bb79_ut06, band alpha, speed fast
# Working on bb79_ut06, band theta, speed slow
# Working on bb79_ut06, band theta, speed fast
# Working on bb79_ut06, band beta, speed slow
# Working on bb79_ut06, band beta, speed fast
# Working on bb79_ut05, band alpha, speed slow
# Working on bb79_ut05, band alpha, speed fast
# Working on bb79_ut05, band theta, speed slow
# Working on bb79_ut05, band theta, speed fast
# Working on bb79_ut05, band beta, speed slow
# Working on bb79_ut05, band beta, speed fast
# Working on bb79_ut04, band alpha, speed slow
# Working on bb79_ut04, band alpha, speed fast
# Working on bb79_ut04, band theta, speed slow
# Working on bb79_ut04, band theta, speed fast
# Working on bb79_ut04, band beta, speed slow
# Working on bb79_ut04, band beta, speed fast
# Working on bb79_ut03, band alpha, speed slow
# Working on bb79_ut03, band alpha, speed fast
# Working on bb79_ut03, band theta, speed slow
# Working on bb79_ut03, band theta, speed fast
# Working on bb79_ut03, band beta, speed slow
# Working on bb79_ut03, band beta, speed fast
# Working on bb79_ut02, band alpha, speed slow
# Working on bb79_ut02, band alpha, speed fast
# Working on bb79_ut02, band theta, speed slow
# Working on bb79_ut02, band theta, speed fast
# Working on bb79_ut02, band beta, speed slow
# Working on bb79_ut02, band beta, speed fast
# Working on bb79_ut01, band alpha, speed slow
# Working on bb79_ut01, band alpha, speed fast
# Working on bb79_ut01, band theta, speed slow
# Working on bb79_ut01, band theta, speed fast
# Working on bb79_ut01, band beta, speed slow
# Working on bb79_ut01, band beta, speed fast
# Working on bb37_ut23, band alpha, speed slow
# Working on bb37_ut23, band alpha, speed fast
# Working on bb37_ut23, band theta, speed slow
# Working on bb37_ut23, band theta, speed fast
# Working on bb37_ut23, band beta, speed slow
# Working on bb37_ut23, band beta, speed fast
# Working on bb37_ut22, band alpha, speed slow
# Working on bb37_ut22, band alpha, speed fast
# Working on bb37_ut22, band theta, speed slow
# Working on bb37_ut22, band theta, speed fast
# Working on bb37_ut22, band beta, speed slow
# Working on bb37_ut22, band beta, speed fast
# Working on bb37_ut21, band alpha, speed slow
# Working on bb37_ut21, band alpha, speed fast
# Working on bb37_ut21, band theta, speed slow
# Working on bb37_ut21, band theta, speed fast
# Working on bb37_ut21, band beta, speed slow
# Working on bb37_ut21, band beta, speed fast
# Working on bb37_ut20, band alpha, speed slow
# Working on bb37_ut20, band alpha, speed fast
# Working on bb37_ut20, band theta, speed slow
# Working on bb37_ut20, band theta, speed fast
# Working on bb37_ut20, band beta, speed slow
# Working on bb37_ut20, band beta, speed fast
# Working on bb37_ut19, band alpha, speed slow
# Working on bb37_ut19, band alpha, speed fast
# Working on bb37_ut19, band theta, speed slow
# Working on bb37_ut19, band theta, speed fast
# Working on bb37_ut19, band beta, speed slow
# Working on bb37_ut19, band beta, speed fast
# Working on bb37_ut18, band alpha, speed slow
# Working on bb37_ut18, band alpha, speed fast
# Working on bb37_ut18, band theta, speed slow
# Working on bb37_ut18, band theta, speed fast
# Working on bb37_ut18, band beta, speed slow
# Working on bb37_ut18, band beta, speed fast
# Working on bb37_ut17, band alpha, speed slow
# Working on bb37_ut17, band alpha, speed fast
# Working on bb37_ut17, band theta, speed slow
# Working on bb37_ut17, band theta, speed fast
# Working on bb37_ut17, band beta, speed slow
# Working on bb37_ut17, band beta, speed fast
# Working on bb37_ut16, band alpha, speed slow
# Working on bb37_ut16, band alpha, speed fast
# Working on bb37_ut16, band theta, speed slow
# Working on bb37_ut16, band theta, speed fast
# Working on bb37_ut16, band beta, speed slow
# Working on bb37_ut16, band beta, speed fast
# Working on bb37_ut15, band alpha, speed slow
# Working on bb37_ut15, band alpha, speed fast
# Working on bb37_ut15, band theta, speed slow
# Working on bb37_ut15, band theta, speed fast
# Working on bb37_ut15, band beta, speed slow
# Working on bb37_ut15, band beta, speed fast
# Working on bb37_ut14, band alpha, speed slow
# Working on bb37_ut14, band alpha, speed fast
# Working on bb37_ut14, band theta, speed slow
# Working on bb37_ut14, band theta, speed fast
# Working on bb37_ut14, band beta, speed slow
# Working on bb37_ut14, band beta, speed fast
# Working on bb37_ut13, band alpha, speed slow
# Working on bb37_ut13, band alpha, speed fast
# Working on bb37_ut13, band theta, speed slow
# Working on bb37_ut13, band theta, speed fast
# Working on bb37_ut13, band beta, speed slow
# Working on bb37_ut13, band beta, speed fast
# Working on bb37_ut12, band alpha, speed slow
# Working on bb37_ut12, band alpha, speed fast
# Working on bb37_ut12, band theta, speed slow
# Working on bb37_ut12, band theta, speed fast
# Working on bb37_ut12, band beta, speed slow
# Working on bb37_ut12, band beta, speed fast
# Working on bb37_ut11, band alpha, speed slow
# Working on bb37_ut11, band alpha, speed fast
# Working on bb37_ut11, band theta, speed slow
# Working on bb37_ut11, band theta, speed fast
# Working on bb37_ut11, band beta, speed slow
# Working on bb37_ut11, band beta, speed fast
# Working on bb37_ut10, band alpha, speed slow
# Working on bb37_ut10, band alpha, speed fast
# Working on bb37_ut10, band theta, speed slow
# Working on bb37_ut10, band theta, speed fast
# Working on bb37_ut10, band beta, speed slow
# Working on bb37_ut10, band beta, speed fast
# Working on bb37_ut09, band alpha, speed slow
# Working on bb37_ut09, band alpha, speed fast
# Working on bb37_ut09, band theta, speed slow
# Working on bb37_ut09, band theta, speed fast
# Working on bb37_ut09, band beta, speed slow
# Working on bb37_ut09, band beta, speed fast
# Working on bb37_ut08, band alpha, speed slow
# Working on bb37_ut08, band alpha, speed fast
# Working on bb37_ut08, band theta, speed slow
# Working on bb37_ut08, band theta, speed fast
# Working on bb37_ut08, band beta, speed slow
# Working on bb37_ut08, band beta, speed fast
# Working on bb37_ut07, band alpha, speed slow
# Working on bb37_ut07, band alpha, speed fast
# Working on bb37_ut07, band theta, speed slow
# Working on bb37_ut07, band theta, speed fast
# Working on bb37_ut07, band beta, speed slow
# Working on bb37_ut07, band beta, speed fast
# Working on bb37_ut06, band alpha, speed slow
# Working on bb37_ut06, band alpha, speed fast
# Working on bb37_ut06, band theta, speed slow
# Working on bb37_ut06, band theta, speed fast
# Working on bb37_ut06, band beta, speed slow
# Working on bb37_ut06, band beta, speed fast
# Working on bb37_ut05, band alpha, speed slow
# Working on bb37_ut05, band alpha, speed fast
# Working on bb37_ut05, band theta, speed slow
# Working on bb37_ut05, band theta, speed fast
# Working on bb37_ut05, band beta, speed slow
# Working on bb37_ut05, band beta, speed fast
# Working on bb37_ut04, band alpha, speed slow
# Working on bb37_ut04, band alpha, speed fast
# Working on bb37_ut04, band theta, speed slow
# Working on bb37_ut04, band theta, speed fast
# Working on bb37_ut04, band beta, speed slow
# Working on bb37_ut04, band beta, speed fast
# Working on bb37_ut03, band alpha, speed slow
# Working on bb37_ut03, band alpha, speed fast
# Working on bb37_ut03, band theta, speed slow
# Working on bb37_ut03, band theta, speed fast
# Working on bb37_ut03, band beta, speed slow
# Working on bb37_ut03, band beta, speed fast
# Working on bb37_ut02, band alpha, speed slow
# Working on bb37_ut02, band alpha, speed fast
# Working on bb37_ut02, band theta, speed slow
# Working on bb37_ut02, band theta, speed fast
# Working on bb37_ut02, band beta, speed slow
# Working on bb37_ut02, band beta, speed fast
# Working on bb37_ut01, band alpha, speed slow
# Working on bb37_ut01, band alpha, speed fast
# Working on bb37_ut01, band theta, speed slow
# Working on bb37_ut01, band theta, speed fast
# Working on bb37_ut01, band beta, speed slow
# Working on bb37_ut01, band beta, speed fast
# Working on bb15_ut23, band alpha, speed slow
# Working on bb15_ut23, band alpha, speed fast
# Working on bb15_ut23, band theta, speed slow
# Working on bb15_ut23, band theta, speed fast
# Working on bb15_ut23, band beta, speed slow
# Working on bb15_ut23, band beta, speed fast
# Working on bb15_ut22, band alpha, speed slow
# Working on bb15_ut22, band alpha, speed fast
# Working on bb15_ut22, band theta, speed slow
# Working on bb15_ut22, band theta, speed fast
# Working on bb15_ut22, band beta, speed slow
# Working on bb15_ut22, band beta, speed fast
# Working on bb15_ut21, band alpha, speed slow
# Working on bb15_ut21, band alpha, speed fast
# Working on bb15_ut21, band theta, speed slow
# Working on bb15_ut21, band theta, speed fast
# Working on bb15_ut21, band beta, speed slow
# Working on bb15_ut21, band beta, speed fast
# Working on bb15_ut20, band alpha, speed slow
# Working on bb15_ut20, band alpha, speed fast
# Working on bb15_ut20, band theta, speed slow
# Working on bb15_ut20, band theta, speed fast
# Working on bb15_ut20, band beta, speed slow
# Working on bb15_ut20, band beta, speed fast
# Working on bb15_ut19, band alpha, speed slow
# Working on bb15_ut19, band alpha, speed fast
# Working on bb15_ut19, band theta, speed slow
# Working on bb15_ut19, band theta, speed fast
# Working on bb15_ut19, band beta, speed slow
# Working on bb15_ut19, band beta, speed fast
# Working on bb15_ut18, band alpha, speed slow
# Working on bb15_ut18, band alpha, speed fast
# Working on bb15_ut18, band theta, speed slow
# Working on bb15_ut18, band theta, speed fast
# Working on bb15_ut18, band beta, speed slow
# Working on bb15_ut18, band beta, speed fast
# Working on bb15_ut17, band alpha, speed slow
# Working on bb15_ut17, band alpha, speed fast
# Working on bb15_ut17, band theta, speed slow
# Working on bb15_ut17, band theta, speed fast
# Working on bb15_ut17, band beta, speed slow
# Working on bb15_ut17, band beta, speed fast
# Working on bb15_ut16, band alpha, speed slow
# Working on bb15_ut16, band alpha, speed fast
# Working on bb15_ut16, band theta, speed slow
# Working on bb15_ut16, band theta, speed fast
# Working on bb15_ut16, band beta, speed slow
# Working on bb15_ut16, band beta, speed fast
# Working on bb15_ut15, band alpha, speed slow
# Working on bb15_ut15, band alpha, speed fast
# Working on bb15_ut15, band theta, speed slow
# Working on bb15_ut15, band theta, speed fast
# Working on bb15_ut15, band beta, speed slow
# Working on bb15_ut15, band beta, speed fast
# Working on bb15_ut14, band alpha, speed slow
# Working on bb15_ut14, band alpha, speed fast
# Working on bb15_ut14, band theta, speed slow
# Working on bb15_ut14, band theta, speed fast
# Working on bb15_ut14, band beta, speed slow
# Working on bb15_ut14, band beta, speed fast
# Working on bb15_ut13, band alpha, speed slow
# Working on bb15_ut13, band alpha, speed fast
# Working on bb15_ut13, band theta, speed slow
# Working on bb15_ut13, band theta, speed fast
# Working on bb15_ut13, band beta, speed slow
# Working on bb15_ut13, band beta, speed fast
# Working on bb15_ut12, band alpha, speed slow
# Working on bb15_ut12, band alpha, speed fast
# Working on bb15_ut12, band theta, speed slow
# Working on bb15_ut12, band theta, speed fast
# Working on bb15_ut12, band beta, speed slow
# Working on bb15_ut12, band beta, speed fast
# Working on bb15_ut11, band alpha, speed slow
# Working on bb15_ut11, band alpha, speed fast
# Working on bb15_ut11, band theta, speed slow
# Working on bb15_ut11, band theta, speed fast
# Working on bb15_ut11, band beta, speed slow
# Working on bb15_ut11, band beta, speed fast
# Working on bb15_ut10, band alpha, speed slow
# Working on bb15_ut10, band alpha, speed fast
# Working on bb15_ut10, band theta, speed slow
# Working on bb15_ut10, band theta, speed fast
# Working on bb15_ut10, band beta, speed slow
# Working on bb15_ut10, band beta, speed fast
# Working on bb15_ut09, band alpha, speed slow
# Working on bb15_ut09, band alpha, speed fast
# Working on bb15_ut09, band theta, speed slow
# Working on bb15_ut09, band theta, speed fast
# Working on bb15_ut09, band beta, speed slow
# Working on bb15_ut09, band beta, speed fast
# Working on bb15_ut08, band alpha, speed slow
# File for bb15_ut08 not found, skipping.
# Working on bb15_ut08, band theta, speed slow
# File for bb15_ut08 not found, skipping.
# Working on bb15_ut08, band beta, speed slow
# File for bb15_ut08 not found, skipping.
# Working on bb15_ut07, band alpha, speed slow
# Working on bb15_ut07, band alpha, speed fast
# Working on bb15_ut07, band theta, speed slow
# Working on bb15_ut07, band theta, speed fast
# Working on bb15_ut07, band beta, speed slow
# Working on bb15_ut07, band beta, speed fast
# Working on bb15_ut06, band alpha, speed slow
# Working on bb15_ut06, band alpha, speed fast
# Working on bb15_ut06, band theta, speed slow
# Working on bb15_ut06, band theta, speed fast
# Working on bb15_ut06, band beta, speed slow
# Working on bb15_ut06, band beta, speed fast
# Working on bb15_ut05, band alpha, speed slow
# Working on bb15_ut05, band alpha, speed fast
# Working on bb15_ut05, band theta, speed slow
# Working on bb15_ut05, band theta, speed fast
# Working on bb15_ut05, band beta, speed slow
# Working on bb15_ut05, band beta, speed fast
# Working on bb15_ut04, band alpha, speed slow
# Working on bb15_ut04, band alpha, speed fast
# Working on bb15_ut04, band theta, speed slow
# Working on bb15_ut04, band theta, speed fast
# Working on bb15_ut04, band beta, speed slow
# Working on bb15_ut04, band beta, speed fast
# Working on bb15_ut03, band alpha, speed slow
# Working on bb15_ut03, band alpha, speed fast
# Working on bb15_ut03, band theta, speed slow
# Working on bb15_ut03, band theta, speed fast
# Working on bb15_ut03, band beta, speed slow
# Working on bb15_ut03, band beta, speed fast
# Working on bb15_ut02, band alpha, speed slow
# Working on bb15_ut02, band alpha, speed fast
# Working on bb15_ut02, band theta, speed slow
# Working on bb15_ut02, band theta, speed fast
# Working on bb15_ut02, band beta, speed slow
# Working on bb15_ut02, band beta, speed fast
# Working on bb15_ut01, band alpha, speed slow
# Working on bb15_ut01, band alpha, speed fast
# Working on bb15_ut01, band theta, speed slow
# Working on bb15_ut01, band theta, speed fast
# Working on bb15_ut01, band beta, speed slow
# Working on bb15_ut01, band beta, speed fast
# Working on bb09_ut23, band alpha, speed slow
# Working on bb09_ut23, band alpha, speed fast
# Working on bb09_ut23, band theta, speed slow
# Working on bb09_ut23, band theta, speed fast
# Working on bb09_ut23, band beta, speed slow
# Working on bb09_ut23, band beta, speed fast
# Working on bb09_ut22, band alpha, speed slow
# Working on bb09_ut22, band alpha, speed fast
# Working on bb09_ut22, band theta, speed slow
# Working on bb09_ut22, band theta, speed fast
# Working on bb09_ut22, band beta, speed slow
# Working on bb09_ut22, band beta, speed fast
# Working on bb09_ut21, band alpha, speed slow
# Working on bb09_ut21, band alpha, speed fast
# Working on bb09_ut21, band theta, speed slow
# Working on bb09_ut21, band theta, speed fast
# Working on bb09_ut21, band beta, speed slow
# Working on bb09_ut21, band beta, speed fast
# Working on bb09_ut20, band alpha, speed slow
# Working on bb09_ut20, band alpha, speed fast
# Working on bb09_ut20, band theta, speed slow
# Working on bb09_ut20, band theta, speed fast
# Working on bb09_ut20, band beta, speed slow
# Working on bb09_ut20, band beta, speed fast
# Working on bb09_ut19, band alpha, speed slow
# Working on bb09_ut19, band alpha, speed fast
# Working on bb09_ut19, band theta, speed slow
# Working on bb09_ut19, band theta, speed fast
# Working on bb09_ut19, band beta, speed slow
# Working on bb09_ut19, band beta, speed fast
# Working on bb09_ut18, band alpha, speed slow
# Working on bb09_ut18, band alpha, speed fast
# Working on bb09_ut18, band theta, speed slow
# Working on bb09_ut18, band theta, speed fast
# Working on bb09_ut18, band beta, speed slow
# Working on bb09_ut18, band beta, speed fast
# Working on bb09_ut17, band alpha, speed slow
# Working on bb09_ut17, band alpha, speed fast
# Working on bb09_ut17, band theta, speed slow
# Working on bb09_ut17, band theta, speed fast
# Working on bb09_ut17, band beta, speed slow
# Working on bb09_ut17, band beta, speed fast
# Working on bb09_ut16, band alpha, speed slow
# Working on bb09_ut16, band alpha, speed fast
# Working on bb09_ut16, band theta, speed slow
# Working on bb09_ut16, band theta, speed fast
# Working on bb09_ut16, band beta, speed slow
# Working on bb09_ut16, band beta, speed fast
# Working on bb09_ut15, band alpha, speed slow
# Working on bb09_ut15, band alpha, speed fast
# Working on bb09_ut15, band theta, speed slow
# Working on bb09_ut15, band theta, speed fast
# Working on bb09_ut15, band beta, speed slow
# Working on bb09_ut15, band beta, speed fast
# Working on bb09_ut14, band alpha, speed slow
# Working on bb09_ut14, band alpha, speed fast
# Working on bb09_ut14, band theta, speed slow
# Working on bb09_ut14, band theta, speed fast
# Working on bb09_ut14, band beta, speed slow
# Working on bb09_ut14, band beta, speed fast
# Working on bb09_ut13, band alpha, speed slow
# Working on bb09_ut13, band alpha, speed fast
# Working on bb09_ut13, band theta, speed slow
# Working on bb09_ut13, band theta, speed fast
# Working on bb09_ut13, band beta, speed slow
# Working on bb09_ut13, band beta, speed fast
# Working on bb09_ut12, band alpha, speed slow
# Working on bb09_ut12, band alpha, speed fast
# Working on bb09_ut12, band theta, speed slow
# Working on bb09_ut12, band theta, speed fast
# Working on bb09_ut12, band beta, speed slow
# Working on bb09_ut12, band beta, speed fast
# Working on bb09_ut11, band alpha, speed slow
# File for bb09_ut11 not found, skipping.
# Working on bb09_ut11, band theta, speed slow
# File for bb09_ut11 not found, skipping.
# Working on bb09_ut11, band beta, speed slow
# File for bb09_ut11 not found, skipping.
# File for bb09_ut10 not found, skipping.
# File for bb09_ut10 not found, skipping.
# File for bb09_ut10 not found, skipping.
# File for bb09_ut10 not found, skipping.
# File for bb09_ut10 not found, skipping.
# File for bb09_ut10 not found, skipping.
# Working on bb09_ut09, band alpha, speed slow
# Working on bb09_ut09, band alpha, speed fast
# Working on bb09_ut09, band theta, speed slow
# Working on bb09_ut09, band theta, speed fast
# Working on bb09_ut09, band beta, speed slow
# Working on bb09_ut09, band beta, speed fast
# Working on bb09_ut08, band alpha, speed slow
# Working on bb09_ut08, band alpha, speed fast
# Working on bb09_ut08, band theta, speed slow
# Working on bb09_ut08, band theta, speed fast
# Working on bb09_ut08, band beta, speed slow
# Working on bb09_ut08, band beta, speed fast
# Working on bb09_ut07, band alpha, speed slow
# Working on bb09_ut07, band alpha, speed fast
# Working on bb09_ut07, band theta, speed slow
# Working on bb09_ut07, band theta, speed fast
# Working on bb09_ut07, band beta, speed slow
# Working on bb09_ut07, band beta, speed fast
# Working on bb09_ut06, band alpha, speed slow
# Working on bb09_ut06, band alpha, speed fast
# Working on bb09_ut06, band theta, speed slow
# Working on bb09_ut06, band theta, speed fast
# Working on bb09_ut06, band beta, speed slow
# Working on bb09_ut06, band beta, speed fast
# Working on bb09_ut05, band alpha, speed slow
# Working on bb09_ut05, band alpha, speed fast
# Working on bb09_ut05, band theta, speed slow
# Working on bb09_ut05, band theta, speed fast
# Working on bb09_ut05, band beta, speed slow
# Working on bb09_ut05, band beta, speed fast
# Working on bb09_ut04, band alpha, speed slow
# Working on bb09_ut04, band alpha, speed fast
# Working on bb09_ut04, band theta, speed slow
# Working on bb09_ut04, band theta, speed fast
# Working on bb09_ut04, band beta, speed slow
# Working on bb09_ut04, band beta, speed fast
# File for bb09_ut03 not found, skipping.
# Working on bb09_ut03, band alpha, speed fast
# File for bb09_ut03 not found, skipping.
# Working on bb09_ut03, band theta, speed fast
# File for bb09_ut03 not found, skipping.
# Working on bb09_ut03, band beta, speed fast
# Working on bb09_ut02, band alpha, speed slow
# Working on bb09_ut02, band alpha, speed fast
# Working on bb09_ut02, band theta, speed slow
# Working on bb09_ut02, band theta, speed fast
# Working on bb09_ut02, band beta, speed slow
# Working on bb09_ut02, band beta, speed fast
# Working on bb09_ut01, band alpha, speed slow
# Working on bb09_ut01, band alpha, speed fast
# Working on bb09_ut01, band theta, speed slow
# Working on bb09_ut01, band theta, speed fast
# Working on bb09_ut01, band beta, speed slow
# Working on bb09_ut01, band beta, speed fast
# Working on bb04_ut23, band alpha, speed slow
# Working on bb04_ut23, band alpha, speed fast
# Working on bb04_ut23, band theta, speed slow
# Working on bb04_ut23, band theta, speed fast
# Working on bb04_ut23, band beta, speed slow
# Working on bb04_ut23, band beta, speed fast
# Working on bb04_ut22, band alpha, speed slow
# Working on bb04_ut22, band alpha, speed fast
# Working on bb04_ut22, band theta, speed slow
# Working on bb04_ut22, band theta, speed fast
# Working on bb04_ut22, band beta, speed slow
# Working on bb04_ut22, band beta, speed fast
# Working on bb04_ut21, band alpha, speed slow
# Working on bb04_ut21, band alpha, speed fast
# Working on bb04_ut21, band theta, speed slow
# Working on bb04_ut21, band theta, speed fast
# Working on bb04_ut21, band beta, speed slow
# Working on bb04_ut21, band beta, speed fast
# Working on bb04_ut20, band alpha, speed slow
# Working on bb04_ut20, band alpha, speed fast
# Working on bb04_ut20, band theta, speed slow
# Working on bb04_ut20, band theta, speed fast
# Working on bb04_ut20, band beta, speed slow
# Working on bb04_ut20, band beta, speed fast
# Working on bb04_ut19, band alpha, speed slow
# Working on bb04_ut19, band alpha, speed fast
# Working on bb04_ut19, band theta, speed slow
# Working on bb04_ut19, band theta, speed fast
# Working on bb04_ut19, band beta, speed slow
# Working on bb04_ut19, band beta, speed fast
# Working on bb04_ut18, band alpha, speed slow
# Working on bb04_ut18, band alpha, speed fast
# Working on bb04_ut18, band theta, speed slow
# Working on bb04_ut18, band theta, speed fast
# Working on bb04_ut18, band beta, speed slow
# Working on bb04_ut18, band beta, speed fast
# Working on bb04_ut17, band alpha, speed slow
# Working on bb04_ut17, band alpha, speed fast
# Working on bb04_ut17, band theta, speed slow
# Working on bb04_ut17, band theta, speed fast
# Working on bb04_ut17, band beta, speed slow
# Working on bb04_ut17, band beta, speed fast
# Working on bb04_ut16, band alpha, speed slow
# Working on bb04_ut16, band alpha, speed fast
# Working on bb04_ut16, band theta, speed slow
# Working on bb04_ut16, band theta, speed fast
# Working on bb04_ut16, band beta, speed slow
# Working on bb04_ut16, band beta, speed fast
# Working on bb04_ut15, band alpha, speed slow
# Working on bb04_ut15, band alpha, speed fast
# Working on bb04_ut15, band theta, speed slow
# Working on bb04_ut15, band theta, speed fast
# Working on bb04_ut15, band beta, speed slow
# Working on bb04_ut15, band beta, speed fast
# Working on bb04_ut14, band alpha, speed slow
# Working on bb04_ut14, band alpha, speed fast
# Working on bb04_ut14, band theta, speed slow
# Working on bb04_ut14, band theta, speed fast
# Working on bb04_ut14, band beta, speed slow
# Working on bb04_ut14, band beta, speed fast
# Working on bb04_ut13, band alpha, speed slow
# Working on bb04_ut13, band alpha, speed fast
# Working on bb04_ut13, band theta, speed slow
# Working on bb04_ut13, band theta, speed fast
# Working on bb04_ut13, band beta, speed slow
# Working on bb04_ut13, band beta, speed fast
# Working on bb04_ut12, band alpha, speed slow
# Working on bb04_ut12, band alpha, speed fast
# Working on bb04_ut12, band theta, speed slow
# Working on bb04_ut12, band theta, speed fast
# Working on bb04_ut12, band beta, speed slow
# Working on bb04_ut12, band beta, speed fast
# Working on bb04_ut11, band alpha, speed slow
# Working on bb04_ut11, band alpha, speed fast
# Working on bb04_ut11, band theta, speed slow
# Working on bb04_ut11, band theta, speed fast
# Working on bb04_ut11, band beta, speed slow
# Working on bb04_ut11, band beta, speed fast
# Working on bb04_ut10, band alpha, speed slow
# Working on bb04_ut10, band alpha, speed fast
# Working on bb04_ut10, band theta, speed slow
# Working on bb04_ut10, band theta, speed fast
# Working on bb04_ut10, band beta, speed slow
# Working on bb04_ut10, band beta, speed fast
# Working on bb04_ut09, band alpha, speed slow
# Working on bb04_ut09, band alpha, speed fast
# Working on bb04_ut09, band theta, speed slow
# Working on bb04_ut09, band theta, speed fast
# Working on bb04_ut09, band beta, speed slow
# Working on bb04_ut09, band beta, speed fast
# Working on bb04_ut08, band alpha, speed slow
# Working on bb04_ut08, band alpha, speed fast
# Working on bb04_ut08, band theta, speed slow
# Working on bb04_ut08, band theta, speed fast
# Working on bb04_ut08, band beta, speed slow
# Working on bb04_ut08, band beta, speed fast
# Working on bb04_ut07, band alpha, speed slow
# Working on bb04_ut07, band alpha, speed fast
# Working on bb04_ut07, band theta, speed slow
# Working on bb04_ut07, band theta, speed fast
# Working on bb04_ut07, band beta, speed slow
# Working on bb04_ut07, band beta, speed fast
# Working on bb04_ut06, band alpha, speed slow
# Working on bb04_ut06, band alpha, speed fast
# Working on bb04_ut06, band theta, speed slow
# Working on bb04_ut06, band theta, speed fast
# Working on bb04_ut06, band beta, speed slow
# Working on bb04_ut06, band beta, speed fast
# Working on bb04_ut05, band alpha, speed slow
# Working on bb04_ut05, band alpha, speed fast
# Working on bb04_ut05, band theta, speed slow
# Working on bb04_ut05, band theta, speed fast
# Working on bb04_ut05, band beta, speed slow
# Working on bb04_ut05, band beta, speed fast
# File for bb04_ut04 not found, skipping.
# Working on bb04_ut04, band alpha, speed fast
# File for bb04_ut04 not found, skipping.
# Working on bb04_ut04, band theta, speed fast
# File for bb04_ut04 not found, skipping.
# Working on bb04_ut04, band beta, speed fast
# Working on bb04_ut03, band alpha, speed slow
# Working on bb04_ut03, band alpha, speed fast
# Working on bb04_ut03, band theta, speed slow
# Working on bb04_ut03, band theta, speed fast
# Working on bb04_ut03, band beta, speed slow
# Working on bb04_ut03, band beta, speed fast
# Working on bb04_ut02, band alpha, speed slow
# Working on bb04_ut02, band alpha, speed fast
# Working on bb04_ut02, band theta, speed slow
# Working on bb04_ut02, band theta, speed fast
# Working on bb04_ut02, band beta, speed slow
# Working on bb04_ut02, band beta, speed fast
# Working on bb04_ut01, band alpha, speed slow
# Working on bb04_ut01, band alpha, speed fast
# Working on bb04_ut01, band theta, speed slow
# Working on bb04_ut01, band theta, speed fast
# Working on bb04_ut01, band beta, speed slow
# Working on bb04_ut01, band beta, speed fast
# Working on bb02_ut23, band alpha, speed slow
# Working on bb02_ut23, band alpha, speed fast
# Working on bb02_ut23, band theta, speed slow
# Working on bb02_ut23, band theta, speed fast
# Working on bb02_ut23, band beta, speed slow
# Working on bb02_ut23, band beta, speed fast
# Working on bb02_ut22, band alpha, speed slow
# Working on bb02_ut22, band alpha, speed fast
# Working on bb02_ut22, band theta, speed slow
# Working on bb02_ut22, band theta, speed fast
# Working on bb02_ut22, band beta, speed slow
# Working on bb02_ut22, band beta, speed fast
# Working on bb02_ut21, band alpha, speed slow
# Working on bb02_ut21, band alpha, speed fast
# Working on bb02_ut21, band theta, speed slow
# Working on bb02_ut21, band theta, speed fast
# Working on bb02_ut21, band beta, speed slow
# Working on bb02_ut21, band beta, speed fast
# Working on bb02_ut20, band alpha, speed slow
# Working on bb02_ut20, band alpha, speed fast
# Working on bb02_ut20, band theta, speed slow
# Working on bb02_ut20, band theta, speed fast
# Working on bb02_ut20, band beta, speed slow
# Working on bb02_ut20, band beta, speed fast
# Working on bb02_ut19, band alpha, speed slow
# Working on bb02_ut19, band alpha, speed fast
# Working on bb02_ut19, band theta, speed slow
# Working on bb02_ut19, band theta, speed fast
# Working on bb02_ut19, band beta, speed slow
# Working on bb02_ut19, band beta, speed fast
# Working on bb02_ut18, band alpha, speed slow
# Working on bb02_ut18, band alpha, speed fast
# Working on bb02_ut18, band theta, speed slow
# Working on bb02_ut18, band theta, speed fast
# Working on bb02_ut18, band beta, speed slow
# Working on bb02_ut18, band beta, speed fast
# Working on bb02_ut17, band alpha, speed slow
# Working on bb02_ut17, band alpha, speed fast
# Working on bb02_ut17, band theta, speed slow
# Working on bb02_ut17, band theta, speed fast
# Working on bb02_ut17, band beta, speed slow
# Working on bb02_ut17, band beta, speed fast
# File for bb02_ut16 not found, skipping.
# Working on bb02_ut16, band alpha, speed fast
# File for bb02_ut16 not found, skipping.
# Working on bb02_ut16, band theta, speed fast
# File for bb02_ut16 not found, skipping.
# Working on bb02_ut16, band beta, speed fast
# Working on bb02_ut15, band alpha, speed slow
# Working on bb02_ut15, band alpha, speed fast
# Working on bb02_ut15, band theta, speed slow
# Working on bb02_ut15, band theta, speed fast
# Working on bb02_ut15, band beta, speed slow
# Working on bb02_ut15, band beta, speed fast
# Working on bb02_ut14, band alpha, speed slow
# Working on bb02_ut14, band alpha, speed fast
# Working on bb02_ut14, band theta, speed slow
# Working on bb02_ut14, band theta, speed fast
# Working on bb02_ut14, band beta, speed slow
# Working on bb02_ut14, band beta, speed fast
# Working on bb02_ut13, band alpha, speed slow
# Working on bb02_ut13, band alpha, speed fast
# Working on bb02_ut13, band theta, speed slow
# Working on bb02_ut13, band theta, speed fast
# Working on bb02_ut13, band beta, speed slow
# Working on bb02_ut13, band beta, speed fast
# Working on bb02_ut12, band alpha, speed slow
# Working on bb02_ut12, band alpha, speed fast
# Working on bb02_ut12, band theta, speed slow
# Working on bb02_ut12, band theta, speed fast
# Working on bb02_ut12, band beta, speed slow
# Working on bb02_ut12, band beta, speed fast
# Working on bb02_ut11, band alpha, speed slow
# Working on bb02_ut11, band alpha, speed fast
# Working on bb02_ut11, band theta, speed slow
# Working on bb02_ut11, band theta, speed fast
# Working on bb02_ut11, band beta, speed slow
# Working on bb02_ut11, band beta, speed fast
# Working on bb02_ut10, band alpha, speed slow
# Working on bb02_ut10, band alpha, speed fast
# Working on bb02_ut10, band theta, speed slow
# Working on bb02_ut10, band theta, speed fast
# Working on bb02_ut10, band beta, speed slow
# Working on bb02_ut10, band beta, speed fast
# Working on bb02_ut09, band alpha, speed slow
# Working on bb02_ut09, band alpha, speed fast
# Working on bb02_ut09, band theta, speed slow
# Working on bb02_ut09, band theta, speed fast
# Working on bb02_ut09, band beta, speed slow
# Working on bb02_ut09, band beta, speed fast
# Working on bb02_ut08, band alpha, speed slow
# Working on bb02_ut08, band alpha, speed fast
# Working on bb02_ut08, band theta, speed slow
# Working on bb02_ut08, band theta, speed fast
# Working on bb02_ut08, band beta, speed slow
# Working on bb02_ut08, band beta, speed fast
# Working on bb02_ut07, band alpha, speed slow
# Working on bb02_ut07, band alpha, speed fast
# Working on bb02_ut07, band theta, speed slow
# Working on bb02_ut07, band theta, speed fast
# Working on bb02_ut07, band beta, speed slow
# Working on bb02_ut07, band beta, speed fast
# Working on bb02_ut06, band alpha, speed slow
# Working on bb02_ut06, band alpha, speed fast
# Working on bb02_ut06, band theta, speed slow
# Working on bb02_ut06, band theta, speed fast
# Working on bb02_ut06, band beta, speed slow
# Working on bb02_ut06, band beta, speed fast
# Working on bb02_ut05, band alpha, speed slow
# Working on bb02_ut05, band alpha, speed fast
# Working on bb02_ut05, band theta, speed slow
# Working on bb02_ut05, band theta, speed fast
# Working on bb02_ut05, band beta, speed slow
# Working on bb02_ut05, band beta, speed fast
# Working on bb02_ut04, band alpha, speed slow
# Working on bb02_ut04, band alpha, speed fast
# Working on bb02_ut04, band theta, speed slow
# Working on bb02_ut04, band theta, speed fast
# Working on bb02_ut04, band beta, speed slow
# Working on bb02_ut04, band beta, speed fast
# Working on bb02_ut03, band alpha, speed slow
# Working on bb02_ut03, band alpha, speed fast
# Working on bb02_ut03, band theta, speed slow
# Working on bb02_ut03, band theta, speed fast
# Working on bb02_ut03, band beta, speed slow
# Working on bb02_ut03, band beta, speed fast
# Working on bb02_ut02, band alpha, speed slow
# Working on bb02_ut02, band alpha, speed fast
# Working on bb02_ut02, band theta, speed slow
# Working on bb02_ut02, band theta, speed fast
# Working on bb02_ut02, band beta, speed slow
# Working on bb02_ut02, band beta, speed fast
# File for bb02_ut01 not found, skipping.
# Working on bb02_ut01, band alpha, speed fast
# File for bb02_ut01 not found, skipping.
# Working on bb02_ut01, band theta, speed fast
# File for bb02_ut01 not found, skipping.
# Working on bb02_ut01, band beta, speed fast
# Working on bb01_ut23, band alpha, speed slow
# Working on bb01_ut23, band alpha, speed fast
# Working on bb01_ut23, band theta, speed slow
# Working on bb01_ut23, band theta, speed fast
# Working on bb01_ut23, band beta, speed slow
# Working on bb01_ut23, band beta, speed fast
# Working on bb01_ut22, band alpha, speed slow
# Working on bb01_ut22, band alpha, speed fast
# Working on bb01_ut22, band theta, speed slow
# Working on bb01_ut22, band theta, speed fast
# Working on bb01_ut22, band beta, speed slow
# Working on bb01_ut22, band beta, speed fast
# Working on bb01_ut21, band alpha, speed slow
# Working on bb01_ut21, band alpha, speed fast
# Working on bb01_ut21, band theta, speed slow
# Working on bb01_ut21, band theta, speed fast
# Working on bb01_ut21, band beta, speed slow
# Working on bb01_ut21, band beta, speed fast
# Working on bb01_ut20, band alpha, speed slow
# Working on bb01_ut20, band alpha, speed fast
# Working on bb01_ut20, band theta, speed slow
# Working on bb01_ut20, band theta, speed fast
# Working on bb01_ut20, band beta, speed slow
# Working on bb01_ut20, band beta, speed fast
# Working on bb01_ut19, band alpha, speed slow
# Working on bb01_ut19, band alpha, speed fast
# Working on bb01_ut19, band theta, speed slow
# Working on bb01_ut19, band theta, speed fast
# Working on bb01_ut19, band beta, speed slow
# Working on bb01_ut19, band beta, speed fast
# Working on bb01_ut18, band alpha, speed slow
# Working on bb01_ut18, band alpha, speed fast
# Working on bb01_ut18, band theta, speed slow
# Working on bb01_ut18, band theta, speed fast
# Working on bb01_ut18, band beta, speed slow
# Working on bb01_ut18, band beta, speed fast
# Working on bb01_ut17, band alpha, speed slow
# Working on bb01_ut17, band alpha, speed fast
# Working on bb01_ut17, band theta, speed slow
# Working on bb01_ut17, band theta, speed fast
# Working on bb01_ut17, band beta, speed slow
# Working on bb01_ut17, band beta, speed fast
# Working on bb01_ut16, band alpha, speed slow
# Working on bb01_ut16, band alpha, speed fast
# Working on bb01_ut16, band theta, speed slow
# Working on bb01_ut16, band theta, speed fast
# Working on bb01_ut16, band beta, speed slow
# Working on bb01_ut16, band beta, speed fast
# Working on bb01_ut15, band alpha, speed slow
# Working on bb01_ut15, band alpha, speed fast
# Working on bb01_ut15, band theta, speed slow
# Working on bb01_ut15, band theta, speed fast
# Working on bb01_ut15, band beta, speed slow
# Working on bb01_ut15, band beta, speed fast
# Working on bb01_ut14, band alpha, speed slow
# Working on bb01_ut14, band alpha, speed fast
# Working on bb01_ut14, band theta, speed slow
# Working on bb01_ut14, band theta, speed fast
# Working on bb01_ut14, band beta, speed slow
# Working on bb01_ut14, band beta, speed fast
# Working on bb01_ut13, band alpha, speed slow
# Working on bb01_ut13, band alpha, speed fast
# Working on bb01_ut13, band theta, speed slow
# Working on bb01_ut13, band theta, speed fast
# Working on bb01_ut13, band beta, speed slow
# Working on bb01_ut13, band beta, speed fast
# Working on bb01_ut12, band alpha, speed slow
# Working on bb01_ut12, band alpha, speed fast
# Working on bb01_ut12, band theta, speed slow
# Working on bb01_ut12, band theta, speed fast
# Working on bb01_ut12, band beta, speed slow
# Working on bb01_ut12, band beta, speed fast
# Working on bb01_ut11, band alpha, speed slow
# Working on bb01_ut11, band alpha, speed fast
# Working on bb01_ut11, band theta, speed slow
# Working on bb01_ut11, band theta, speed fast
# Working on bb01_ut11, band beta, speed slow
# Working on bb01_ut11, band beta, speed fast
# Working on bb01_ut10, band alpha, speed slow
# Working on bb01_ut10, band alpha, speed fast
# Working on bb01_ut10, band theta, speed slow
# Working on bb01_ut10, band theta, speed fast
# Working on bb01_ut10, band beta, speed slow
# Working on bb01_ut10, band beta, speed fast
# Working on bb01_ut09, band alpha, speed slow
# Working on bb01_ut09, band alpha, speed fast
# Working on bb01_ut09, band theta, speed slow
# Working on bb01_ut09, band theta, speed fast
# Working on bb01_ut09, band beta, speed slow
# Working on bb01_ut09, band beta, speed fast
# Working on bb01_ut08, band alpha, speed slow
# Working on bb01_ut08, band alpha, speed fast
# Working on bb01_ut08, band theta, speed slow
# Working on bb01_ut08, band theta, speed fast
# Working on bb01_ut08, band beta, speed slow
# Working on bb01_ut08, band beta, speed fast
# Working on bb01_ut07, band alpha, speed slow
# Working on bb01_ut07, band alpha, speed fast
# Working on bb01_ut07, band theta, speed slow
# Working on bb01_ut07, band theta, speed fast
# Working on bb01_ut07, band beta, speed slow
# Working on bb01_ut07, band beta, speed fast
# Working on bb01_ut06, band alpha, speed slow
# Working on bb01_ut06, band alpha, speed fast
# Working on bb01_ut06, band theta, speed slow
# Working on bb01_ut06, band theta, speed fast
# Working on bb01_ut06, band beta, speed slow
# Working on bb01_ut06, band beta, speed fast
# Working on bb01_ut05, band alpha, speed slow
# Working on bb01_ut05, band alpha, speed fast
# Working on bb01_ut05, band theta, speed slow
# Working on bb01_ut05, band theta, speed fast
# Working on bb01_ut05, band beta, speed slow
# Working on bb01_ut05, band beta, speed fast
# Working on bb01_ut04, band alpha, speed slow
# Working on bb01_ut04, band alpha, speed fast
# Working on bb01_ut04, band theta, speed slow
# Working on bb01_ut04, band theta, speed fast
# Working on bb01_ut04, band beta, speed slow
# Working on bb01_ut04, band beta, speed fast
# Working on bb01_ut03, band alpha, speed slow
# Working on bb01_ut03, band alpha, speed fast
# Working on bb01_ut03, band theta, speed slow
# Working on bb01_ut03, band theta, speed fast
# Working on bb01_ut03, band beta, speed slow
# Working on bb01_ut03, band beta, speed fast
# Working on bb01_ut02, band alpha, speed slow
# Working on bb01_ut02, band alpha, speed fast
# Working on bb01_ut02, band theta, speed slow
# Working on bb01_ut02, band theta, speed fast
# Working on bb01_ut02, band beta, speed slow
# Working on bb01_ut02, band beta, speed fast
# Working on bb01_ut01, band alpha, speed slow
# Working on bb01_ut01, band alpha, speed fast
# Working on bb01_ut01, band theta, speed slow
# Working on bb01_ut01, band theta, speed fast
# Working on bb01_ut01, band beta, speed slow
# Working on bb01_ut01, band beta, speed fast

# %%
import imageio

images = []
for i in range(98):
    filename = f"imgs{i}.png"
    images.append(imageio.imread(filename))

imageio.mimsave("animation3.gif", images, fps=3)
# Out:
# C:\Users\marti\AppData\Local\Temp\ipykernel_40224\38099984.py:6: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   images.append(imageio.imread(filename))
